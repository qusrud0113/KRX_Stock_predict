# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('mode.chained_assignment',  None)
data = pd.read_csv('train.csv')
sub = pd.read_csv('sample_submission.csv')

data['일자'] = pd.to_datetime(data['일자'], format='%Y%m%d')
data = data.rename(columns={'일자' : 'ds', '종가' : 'y'})
data
# Out:
#                ds     종목코드     종목명      거래량     시가     고가     저가      y
# 0      2021-06-01  A060310      3S   166690   2890   2970   2885   2920
# 1      2021-06-01  A095570  AJ네트웍스    63836   5860   5940   5750   5780
# 2      2021-06-01  A006840   AK홀딩스   103691  35500  35600  34150  34400
# 3      2021-06-01  A054620     APS   462544  14600  14950  13800  14950
# 4      2021-06-01  A265520   AP시스템   131987  29150  29150  28800  29050
# ...           ...      ...     ...      ...    ...    ...    ...    ...
# 987995 2023-05-30  A189980  흥국에프엔비   272284   3005   3035   2955   2980
# 987996 2023-05-30  A000540    흥국화재    50218   3250   3255   3195   3215
# 987997 2023-05-30  A003280    흥아해운   130664   1344   1395   1340   1370
# 987998 2023-05-30  A037440      희림   141932   9170   9260   9170   9200
# 987999 2023-05-30  A238490      힘스  2611843   6410   8220   6300   8220
#
# [988000 rows x 8 columns]

# %%
code = [str(i).replace('A', '') for i in data['종목코드'].unique()]
ymd = data['ds'].unique()

# %%
from pykrx import stock
from tqdm.auto import tqdm
import time

# 수정 종가를 얻기 위해 pykrx 라이브러리 사용
# time.sleep은 크롤링이 막히는 것을 방지
start_date = str(ymd[:1][0])
last_date = str(ymd[-1:][0])
modified_df = pd.DataFrame()

for i in tqdm(code):
    st = stock.get_market_ohlcv_by_date(start_date, last_date, i, adjusted=True).reset_index(drop=False)
    # 티커명을 넣어야지 구분 가능
    st['ticker'] = str(i)
    modified_df = pd.concat([modified_df,st], axis = 0)
    time.sleep(1)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 12
#       9 modified_df = pd.DataFrame()
#      11 for i in tqdm(code):
# ---> 12     st = stock.get_market_ohlcv_by_date(start_date, last_date, i, adjusted=True).reset_index(drop=False)
#      13     # 티커명을 넣어야지 구분 가능
#      14     st['ticker'] = str(i)
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/pykrx/stock/stock_api.py:230, in get_market_ohlcv_by_date(fromdate, todate, ticker, freq, adjusted, name_display)
#     227 fromdate = fromdate.replace("-", "")
#     228 todate = todate.replace("-", "")
# --> 230 df = krx.get_market_ohlcv_by_date(fromdate, todate, ticker, adjusted)
#     232 if name_display:
#     233     df.columns.name = get_market_ticker_name(ticker)
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/pykrx/website/comm/util.py:8, in dataframe_empty_handler.<locals>.wrapper(*args, **kwargs)
#       6 def wrapper(*args, **kwargs):
#       7     try:
# ----> 8         return func(*args, **kwargs)
#       9     except (AttributeError, KeyError, TypeError) as e:
#      10         logging.info(args, kwargs)
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/pykrx/website/krx/market/wrap.py:50, in get_market_ohlcv_by_date(fromdate, todate, ticker, adjusted)
#      26 @dataframe_empty_handler
#      27 def get_market_ohlcv_by_date(fromdate: str, todate: str, ticker: str,
#      28                              adjusted: bool = True) -> DataFrame:
#      29     """일자별로 정렬된 특정 종목의 OHLCV
#      30
#      31     Args:
#    (...)
#      47             2015-07-23  1244000  1253000  1234000  1234000  208965  259446564000 -1.519531
#      48     """  # pylint: disable=line-too-long # noqa: E501
# ---> 50     isin = get_stock_ticker_isin(ticker)
#      51     adjusted = 2 if adjusted else 1
#      52     df = 개별종목시세().fetch(fromdate, todate, isin, adjusted)
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/pykrx/website/comm/util.py:8, in dataframe_empty_handler.<locals>.wrapper(*args, **kwargs)
#       6 def wrapper(*args, **kwargs):
#       7     try:
# ----> 8         return func(*args, **kwargs)
#       9     except (AttributeError, KeyError, TypeError) as e:
#      10         logging.info(args, kwargs)
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/pykrx/website/krx/market/ticker.py:62, in get_stock_ticker_isin(ticker)
#      60 @dataframe_empty_handler
#      61 def get_stock_ticker_isin(ticker):
# ---> 62     s = StockTicker().get(ticker)
#      63     return s['ISIN']
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/pykrx/website/comm/util.py:30, in singleton.<locals>.class_w.__init__(self, *args, **kwargs)
#      28 if self._sealed:
#      29     return
# ---> 30 super(class_w, self).__init__(*args, **kwargs)
#      31 self._sealed = True
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/pykrx/website/krx/market/ticker.py:12, in StockTicker.__init__(self)
#      11 def __init__(self):
# ---> 12     self.listed = self.__fetch(상장종목검색)
#      13     self.delisted = self.__fetch(상폐종목검색)
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/pykrx/website/comm/util.py:8, in dataframe_empty_handler.<locals>.wrapper(*args, **kwargs)
#       6 def wrapper(*args, **kwargs):
#       7     try:
# ----> 8         return func(*args, **kwargs)
#       9     except (AttributeError, KeyError, TypeError) as e:
#      10         logging.info(args, kwargs)
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/pykrx/website/krx/market/ticker.py:19, in StockTicker.__fetch(self, what, market)
#      17 market_dict = {"코스피": "STK", "코스닥": "KSQ", "코넥스": "KNX", "전체": "ALL"}
#      18 market = market_dict.get(market, "ALL")
# ---> 19 df = what().fetch(market)
#      20 df = df[['short_code', 'codeName', 'full_code', 'marketName']]
#      21 df = df.replace("유가증권", "코스피")
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/pykrx/website/krx/market/core.py:36, in 상장종목검색.fetch(self, mktsel, searchText)
#      11 def fetch(self, mktsel: str = "ALL", searchText: str = "") -> DataFrame:
#      12     """[12003] 개별종목 시세 추이에서 검색 버튼 눌러 활성화 되는 종목 검색창
#      13         스크래핑
#      14
#    (...)
#      34             KOSDAQ        16
#      35     """
# ---> 36     result = self.read(locale="ko_KR", mktsel=mktsel,
#      37                        searchText=searchText, typeNo=0)
#      38     return DataFrame(result['block1'])
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/pykrx/website/krx/krxio.py:56, in KrxWebIo.read(self, **params)
#      54     return result
#      55 else:
# ---> 56     resp = super().read(**params)
#      57     return resp.json()
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/pykrx/website/comm/webio.py:26, in Post.read(self, **params)
#      25 def read(self, **params):
# ---> 26     resp = requests.post(self.url, headers=self.headers, data=params)
#      27     return resp
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/requests/adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     484     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#     502     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/rapids-23.04/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
modified_df.to_csv("modified_df.csv")

# %%
modified_df = pd.read_csv("modified_df.csv")

# %%
modified_df['ticker'] = [str(i).zfill(6) for i in modified_df['ticker']]

# %%
modified_df
# Out:
#         Unnamed: 0          날짜    시가    고가    저가    종가      거래량         거래대금  \
# 0                0  2021-06-01  2890  2970  2885  2920   166690    487455970
# 1                1  2021-06-02  2915  2975  2830  2900   134833    388795625
# 2                2  2021-06-03  2900  2925  2875  2900   144470    419668300
# 3                3  2021-06-04  2930  3120  2920  2950   934224   2840373820
# 4                4  2021-06-07  3000  3150  2955  3150   946560   2929678225
# ...            ...         ...   ...   ...   ...   ...      ...          ...
# 987995         489  2023-05-23  6710  6710  6420  6430    40981    266207710
# 987996         490  2023-05-24  6400  6490  6210  6320    19392    123635550
# 987997         491  2023-05-25  6340  6400  6270  6330     6457     40862130
# 987998         492  2023-05-26  6330  6410  6300  6330     8905     56621540
# 987999         493  2023-05-30  6410  8220  6300  8220  2611843  21069895350
#
#           등락률  ticker
# 0        1.04  060310
# 1       -0.68  060310
# 2        0.00  060310
# 3        1.72  060310
# 4        6.78  060310
# ...       ...     ...
# 987995  -4.17  238490
# 987996  -1.71  238490
# 987997   0.16  238490
# 987998   0.00  238490
# 987999  29.86  238490
#
# [988000 rows x 10 columns]

# %%
modified_df = modified_df.drop(columns = ['Unnamed: 0'])

# %%
diff_1 = modified_df.set_index(['ticker', '날짜'])\
                    .groupby(level='ticker')['종가']\
                    .transform(lambda x: x.sort_index().diff())\
                    .reset_index()\
                    .rename(columns = {'종가':'d1c'})

# %%
modified_df = pd.merge(modified_df, diff_1, on = ['ticker' , '날짜'])
modified_df
# Out:
#                 날짜    시가    고가    저가    종가      거래량         거래대금    등락률  \
# 0       2021-06-01  2890  2970  2885  2920   166690    487455970   1.04
# 1       2021-06-02  2915  2975  2830  2900   134833    388795625  -0.68
# 2       2021-06-03  2900  2925  2875  2900   144470    419668300   0.00
# 3       2021-06-04  2930  3120  2920  2950   934224   2840373820   1.72
# 4       2021-06-07  3000  3150  2955  3150   946560   2929678225   6.78
# ...            ...   ...   ...   ...   ...      ...          ...    ...
# 987995  2023-05-23  6710  6710  6420  6430    40981    266207710  -4.17
# 987996  2023-05-24  6400  6490  6210  6320    19392    123635550  -1.71
# 987997  2023-05-25  6340  6400  6270  6330     6457     40862130   0.16
# 987998  2023-05-26  6330  6410  6300  6330     8905     56621540   0.00
# 987999  2023-05-30  6410  8220  6300  8220  2611843  21069895350  29.86
#
#         ticker     d1c
# 0       060310     NaN
# 1       060310   -20.0
# 2       060310     0.0
# 3       060310    50.0
# 4       060310   200.0
# ...        ...     ...
# 987995  238490  -280.0
# 987996  238490  -110.0
# 987997  238490    10.0
# 987998  238490     0.0
# 987999  238490  1890.0
#
# [988000 rows x 10 columns]

# %%
modified_df = modified_df.rename(columns={'날짜': 'ds', '종가' : 'y'})
modified_df
# Out:
#                 ds    시가    고가    저가     y      거래량         거래대금    등락률  \
# 0       2021-06-01  2890  2970  2885  2920   166690    487455970   1.04
# 1       2021-06-02  2915  2975  2830  2900   134833    388795625  -0.68
# 2       2021-06-03  2900  2925  2875  2900   144470    419668300   0.00
# 3       2021-06-04  2930  3120  2920  2950   934224   2840373820   1.72
# 4       2021-06-07  3000  3150  2955  3150   946560   2929678225   6.78
# ...            ...   ...   ...   ...   ...      ...          ...    ...
# 987995  2023-05-23  6710  6710  6420  6430    40981    266207710  -4.17
# 987996  2023-05-24  6400  6490  6210  6320    19392    123635550  -1.71
# 987997  2023-05-25  6340  6400  6270  6330     6457     40862130   0.16
# 987998  2023-05-26  6330  6410  6300  6330     8905     56621540   0.00
# 987999  2023-05-30  6410  8220  6300  8220  2611843  21069895350  29.86
#
#         ticker     d1c
# 0       060310     NaN
# 1       060310   -20.0
# 2       060310     0.0
# 3       060310    50.0
# 4       060310   200.0
# ...        ...     ...
# 987995  238490  -280.0
# 987996  238490  -110.0
# 987997  238490    10.0
# 987998  238490     0.0
# 987999  238490  1890.0
#
# [988000 rows x 10 columns]

# %%
# !pip install prophet

# %%
from prophet import Prophet
from pandas.tseries.offsets import CustomBusinessDay
import numpy as np

RANDOM_SEED = 113
np.random.seed(RANDOM_SEED)

def ph_train(df):
    pred = pd.DataFrame()
    pred['y'] = None
    pred['종목코드'] = None

    pred_y = []
    pred_code = []
    for code in df['ticker'].unique():
        d = df[df['ticker'] == code].reset_index().drop(['index','ticker'], axis=1).sort_values('ds')
        
        model = Prophet(growth = 'linear',
                        seasonality_mode = 'additive',
                        yearly_seasonality = 'auto',
                        weekly_seasonality = 'auto',
                        daily_seasonality = 'auto',
                        holidays = None,
                        changepoint_prior_scale = 0.01
                       )
        model.fit(d)
        bday = CustomBusinessDay(weekmask='Mon Tue Wed Thu Fri')
        future = pd.DataFrame()
        future['ds'] = pd.date_range(start='2023-05-31', periods=16, freq=bday)
        future = future[future['ds'] != '2023-06-06']
        
        forecast = model.predict(future)
        pred_y.append(forecast['yhat'].diff().sum())
        pred_code.append(str(code))
    
    pred['y'] = pred_y
    pred['종목코드'] = pred_code
    
    return pred

pred = ph_train(modified_df)
# Out:
# 09:38:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:36 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:36 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:36 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:36 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:36 - cmdstanpy - INFO - Chain [1] start processing
# 09:38
- cmdstanpy - INFO - Chain [1] done processing
# 09:41:21 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:21 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:21 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:21 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:21 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:21 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:21 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:21 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:21 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:21 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:21 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:21 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:21 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:22 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:23 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:24 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:25 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:27 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:28 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:29 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:30 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:33 - cmdstanpy - INFO - Chain [1] done processing

# %%
pred['종목코드'] = 'A' + pred['종목코드']

# %%
pred = pred.sort_values('y', ascending=False)
save_pred = pred.reset_index().drop(['index', 'y'], axis=1).reset_index().rename(columns={'index' : '순위'})

# %%
save_pred['종목코드'] = save_pred['종목코드'].astype(str)

# %%
pred
# Out:
#                  y     종목코드
# 1127  45153.532429  A086520
# 607   14112.806191  A086900
# 1738  13231.977662  A003670
# 319   12720.460570  A003920
# 162   12212.321146  A005490
# ...            ...      ...
# 97    -5967.045691  A002380
# 131   -6018.747886  A051900
# 1971  -6955.720011  A298050
# 18    -9534.579948  A097950
# 1653 -11399.998385  A003240
#
# [2000 rows x 2 columns]

# %%
merged = pd.merge(sub, save_pred, on='종목코드').drop('순위_x', axis=1).rename(columns={'순위_y' : '순위'})
merged['순위'] = merged['순위'] + 1
merged.to_csv('prophet_230711_adjust(1).csv', index=False)

# %%
merged
